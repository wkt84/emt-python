# %% [markdown]
# <a href="https://colab.research.google.com/github/wkt84/emt-python/blob/master/notebook/Python05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydicom
import pydicom
# Out:
# ...
#     100% |████████████████████████████████| 7.0MB 4.4MB/s
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !wget "https://drive.google.com/uc?export=download&id=14WmF1XCb0_yatN3YnWaoGqk_i8gjwe32" -O DICOMdata.tar.gz
# Out:
# --2018-12-04 09:32:38--  https://drive.google.com/uc?export=download&id=14WmF1XCb0_yatN3YnWaoGqk_i8gjwe32
# Resolving drive.google.com (drive.google.com)... 74.125.31.102, 74.125.31.113, 74.125.31.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.31.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-6c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uhhflu17cih7voallk4ac4j0hia4d2kd/1543910400000/09677920136733302838/*/14WmF1XCb0_yatN3YnWaoGqk_i8gjwe32?e=download [following]
# ...
# --2018-12-04 09:32:42--  https://doc-14-6c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uhhflu17cih7voallk4ac4j0hia4d2kd/1543910400000/09677920136733302838/*/14WmF1XCb0_yatN3YnWaoGqk_i8gjwe32?e=download
# Resolving doc-14-6c-docs.googleusercontent.com (doc-14-6c-docs.googleusercontent.com)... 172.217.204.132, 2607:f8b0:400c:c15::84
# ...

# %%
mkdir python

# %%
mv DICOMdata.tar.gz python

# %%
ls
# Out:
# sample_data/

# %%
cd '/gdrive/My Drive/python/DICOMdata/'
# Out:
# /gdrive/My Drive/python/DICOMdata

# %%
ct1 = pydicom.dcmread('CT.002445.1.dcm')
print(ct1)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20181113'
# (0008, 0013) Instance Creation Time              TM: '103357.974000'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.55.3.252317953.12119.1157458294.653.1
# (0008, 0020) Study Date                          DA: '20060905'
# (0008, 0021) Series Date                         DA: '20060905'
# (0008, 0023) Content Date                        DA: '20060905'
# (0008, 0030) Study Time                          TM: '142544'
# (0008, 0031) Series Time                         TM: '142641'
# (0008, 0033) Content Time                        TM: '142653'
# (0008, 0050) Accession Number                    SH: '442542.001'
# (0008, 0060) Modality                            CS: 'CT'
# ...

# %%
ct1.ImagePositionPatient
# Out:
# ['-250', '-250', '130']

# %%
ct1.PixelSpacing
# Out:
# ['9.76562e-1', '9.76562e-1']

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data.flatten())
plt.plot()
# Out:
# []

# %%
hu = ct1.pixel_array * ct1.RescaleSlope + ct1.RescaleIntercept

# %%
left = ct1.ImagePositionPatient[0]
right = left + ct1.Columns*ct1.PixelSpacing[1]
top = ct1.ImagePositionPatient[1]
bottom = top + ct1.Rows*ct1.PixelSpacing[0]

# %%
plt.style.use('grayscale')
plt.grid(None)
plt.imshow(hu, extent=(left, right, bottom, top))
plt.show()

# %%
import numpy as np

# %%
plt.grid(None)
plt.imshow(hu, vmin=-50, vmax=500)

# %%
plt.grid(None)
plt.imshow(hu, vmin=-300, vmax=500)
plt.savefig('../test.png')

# %%
print(left, right)
# Out:
# -250 249.99974400000002

# %%
ct1.PixelSpacing[0] * 512
# Out:
# 499.999744

# %%
data = np.arange(25).reshape(5,5)

# %%
extent = (0, 5, 5, 0)

# %%
plt.grid(None)
plt.imshow(data, extent=extent)
plt.plot([1,3], [4,3])
